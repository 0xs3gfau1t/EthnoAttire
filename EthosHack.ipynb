# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/all/" .

# %%
import random
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
names =   [
    "Hāku patāsi",
    "Nyapu Shikha",
    "Tapalan",
    "Haku Tapli",
    "Hansuli",
    "Mangiya",
    "Ali Band",
    "Bijaith",
    "tharu_waist_chain",
    "tharu_head_cloth",
    "kanthula",
    "tharu_broad_wrist_band",
    "Sirbandi",
    "Chura",
    "potey",
    "patuki",
    "dori",
    "dhungri",
    "gunyo",
    "cholo",
    "sirful",
    "teekma",
    "naugedi",
    "chyapte_sun",
  ]

# %%
text = """
path: /content/a;;
train: /content/all/train
val: /content/all/test

nc: 24
names:
    [
    "Hāku patāsi",
    "Nyapu Shikha",
    "Tapalan",
    "Haku Tapli",
    "Hansuli",
    "Mangiya",
    "Ali Band",
    "Bijaith",
    "tharu_waist_chain",
    "tharu_head_cloth",
    "kanthula",
    "tharu_broad_wrist_band",
    "Sirbandi",
    "Chura",
    "potey",
    "patuki",
    "dori",
    "dhungri",
    "gunyo",
    "cholo",
    "sirful",
    "teekma",
    "naugedi",
    "chyapte_sun",
  ]

"""
yaml_file = "./all/data.yaml"

with open(yaml_file,"w") as f:
  # print(text)
  f.write(text)

# %%
# !pip install -U ultralytics --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 16.5 MB/s eta 0:00:00

# %%
! yolo task=detect \
mode=train \
model=yolov8s.pt \
data=./all/data.yaml \
epochs=50 \
batch = 32 \
imgsz=640
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
